# %%
import random

s1=[]
s1.clear()

for i in range(10):
    note =random.randrange(1, 6)
    s1.append(note)
    
    
import matplotlib.pyplot as plt

plt.plot(s1)
plt.show()

# %%
import random


s1=[]
s1.clear()


for i in range(10):
    note =random.randrange(1, 6)
    if note == 1:
        s1.append(55)
    if note == 2:
        s1.append(57)
    if note == 3:
        s1.append(60)
    if note == 4:
        s1.append(62)
    if note == 5:
        s1.append(64)
        s1.append(62) 
    
import matplotlib.pyplot as plt

plt.plot(s1)
plt.show()

# %%
from music21 import *
import random

s1 = stream.Stream();
s1.clear()
s1.insert(0, metadata.Metadata())
s1.metadata.title = '계면조 작곡 '
s1.metadata.composer = '온석대학원대학교'
s1.insert(0, meter.TimeSignature('12/8'))
s1.keySignature= key.KeySignature(-3)

# %%
from music21 import *
import random

s1 = stream.Stream();
s1.clear()
s1.insert(0, metadata.Metadata())
s1.metadata.title = '계면조 작곡 '
s1.metadata.composer = '온석대학원대학교'
s1.insert(0, meter.TimeSignature('12/8'))
s1.keySignature= key.KeySignature(-3)


for i in range(100):
    randomnote =random.randrange(1, 6)
    if randomnote == 1:
        n1 = note.Note(55)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 2:
        n1 = note.Note(57)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 3:
        n1 = note.Note(60)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 4:
        n1 = note.Note(62)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 5:
        n1 = note.Note(64)
        n1.quarterLength=0.125
        s1.append(n1)
        n1 = note.Note(62)
        n1.quarterLength=0.375
        s1.append(n1)
    
#import matplotlib.pyplot as plt

#plt.plot(s1)
#plt.show()

# %%
s1.show()

# %%
s1.show('midi')
# Out:
#                 <div id="midiPlayerDiv2199"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv2199");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>

# %%
note_or_rest = random.randrange(1, 7)
print(note_or_rest)
if note_or_rest>6:
    print("쉼표")
else:
    print("음표")
# Out:
# 6
# 음표

# %%
note_or_rest = random.randrange(1, 8)
print(note_or_rest)
if note_or_rest>6:
    print("말고기")
else:
    print("양고기")
# Out:
# 5
# 양고기

# %%
from music21 import *
import random

s1 = stream.Stream();
s1.clear()
s1.insert(0, metadata.Metadata())
s1.metadata.title = '계면조 작곡 '
s1.metadata.composer = '온석대학원대학교'
s1.insert(0, meter.TimeSignature('12/8'))
s1.keySignature= key.KeySignature(-3)

# %%
note_or_rest = random.randrange(1, 7)
print(note_or_rest)
if note_or_rest>6:
    n1 = note.Rest(55)
    random_length = random.randrange(1, 4) * 0.25
    n1.quarterLength=random_length
    print("쉼표")   
else:
    n1 = note.Note(64)
    n1.quarterLength=0.125
    s1.append(n1)
    n1 = note.Note(62)
    n1.quarterLength=0.375
    print("음표")   

s1.append(n1)
# Out:
# 6
# 음표

# %%
s1.show()

# %%
note_or_rest = random.randrange(1, 7)
print(note_or_rest)
if note_or_rest>6:

    print("쉼표")   
else:

    print("음표")
# Out:
# 6
# 음표

# %%
note_or_rest = random.randrange(1, 8)
print(note_or_rest)
if note_or_rest>6:
    print("말고기")
else:
    print("양고기")
# Out:
# 4
# 양고기

# %%
from music21 import *
import random

s1 = stream.Stream();
s1.clear()
s1.insert(0, metadata.Metadata())
s1.metadata.title = '계면조 작곡 '
s1.metadata.composer = '온석대학원대학교'
s1.insert(0, meter.TimeSignature('12/8'))
s1.keySignature= key.KeySignature(-3)


for i in range(100):
    randomnote =random.randrange(1, 6)
    if randomnote == 1:
        n1 = note.Note(55)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 2:
        n1 = note.Note(57)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 3:
        n1 = note.Note(60)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 4:
        n1 = note.Note(62)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 5:
        n1 = note.Note(64)
        n1.quarterLength=0.125
        s1.append(n1)
        n1 = note.Note(62)
        n1.quarterLength=0.375
        s1.append(n1)
    
#import matplotlib.pyplot as plt

#plt.plot(s1)
#plt.show()

# %%
from music21 import *
import random

s1 = stream.Stream();
s1.clear()
s1.insert(0, metadata.Metadata())
s1.metadata.title = '계면조 작곡 '
s1.metadata.composer = '온석대학원대학교'
s1.insert(0, meter.TimeSignature('12/8'))
s1.keySignature= key.KeySignature(-3)

for i in range(100):
    note_or_rest = random.randrange(1, 10)
    print(note_or_rest)
    if note_or_rest>6:
        n1 = note.Rest(55)
        random_length = random.randrange(1, 4) * 0.25
        n1.quarterLength=random_length
        s1.append(n1)
        
        print("쉼표")   
    else:
        randomnote =random.randrange(1, 6)
        if randomnote == 1:
            n1 = note.Note(55)
            n1.quarterLength=0.5
            s1.append(n1)
        if randomnote == 2:
            n1 = note.Note(57)
            n1.quarterLength=0.5
            s1.append(n1)
        if randomnote == 3:
            n1 = note.Note(60)
            n1.quarterLength=0.5
            s1.append(n1)
        if randomnote == 4:
            n1 = note.Note(62)
            n1.quarterLength=0.5
            s1.append(n1)
        if randomnote == 5:
            n1 = note.Note(64)
            n1.quarterLength=0.125
            s1.append(n1)
            n1 = note.Note(62)
            n1.quarterLength=0.375
            s1.append(n1)
        print("음표")
# Out:
# 8
# 쉼표
# 6
# 음표
# 5
# 음표
# 9
# 쉼표
# 9
# 쉼표
# 8
# 쉼표
# 2
# 음표
# 2
# 음표
# 9
# 쉼표
# 7
# 쉼표
# 1
# 음표
# 9
# 쉼표
# 3
# 음표
# 4
# 음표
# 4
# 음표
# 2
# 음표
# 8
# 쉼표
# 9
# 쉼표
# 1
# 음표
# 6
# 음표
# 5
# 음표
# 3
# 음표
# 2
# 음표
# 8
# 쉼표
# 6
# 음표
# 3
# 음표
# 5
# 음표
# 7
# 쉼표
# 8
# 쉼표
# 3
# 음표
# 6
# 음표
# 1
# 음표
# 6
# 음표
# 7
# 쉼표
# 8
# 쉼표
# 5
# 음표
# 1
# 음표
# 4
# 음표
# 3
# 음표
# 9
# 쉼표
# 5
# 음표
# 2
# 음표
# 3
# 음표
# 3
# 음표
# 7
# 쉼표
# 4
# 음표
# 1
# 음표
# 8
# 쉼표
# 6
# 음표
# 3
# 음표
# 9
# 쉼표
# 1
# 음표
# 1
# 음표
# 7
# 쉼표
# 9
# 쉼표
# 4
# 음표
# 6
# 음표
# 8
# 쉼표
# 4
# 음표
# 5
# 음표
# 5
# 음표
# 2
# 음표
# 3
# 음표
# 1
# 음표
# 6
# 음표
# 9
# 쉼표
# 3
# 음표
# 7
# 쉼표
# 6
# 음표
# 8
# 쉼표
# 3
# 음표
# 6
# 음표
# 6
# 음표
# 3
# 음표
# 4
# 음표
# 4
# 음표
# 7
# 쉼표
# 8
# 쉼표
# 3
# 음표
# 2
# 음표
# 5
# 음표
# 3
# 음표
# 7
# 쉼표
# 9
# 쉼표
# 6
# 음표
# 8
# 쉼표
# 7
# 쉼표
# 5
# 음표
# 2
# 음표
# 4
# 음표
# 3
# 음표
# 9
# 쉼표
# 4
# 음표
# 3
# 음표
# 3
# 음표
# 5
# 음표
# 1
# 음표
# 1
# 음표
# 9
# 쉼표
# 5
# 음표

# %%
s1.show()

# %%
s1.show('midi')
# Out:
#                 <div id="midiPlayerDiv4414"></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer("#midiPlayerDiv4414");
#                                mp.base64Load("data:audio/midi;base64,...");
#                         });
#                 </script>

# %%
s1.write("midi", "gaemyun.mid")
# Out:
# 'gaemyun.mid'

# %%
s1.analyze('key')
# Out:
# <music21.key.Key of g minor>

# %%
s1.plot('histogram', 'pitch')
# Out:
# <music21.graph.plot.HistogramPitchSpace for <music21.stream.Stream 0x7f9f5b131820>>

# %%
s1.plot('pianoroll')
# Out:
# <music21.graph.plot.HorizontalBarPitchSpaceOffset for <music21.stream.Stream 0x7f9f5b131820>>

# %%
from music21 import *

doduriakbo = converter.parse('doduri.xml')
components = []
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 from music21 import *
# ----> 3 doduriakbo = converter.parse('doduri.xml')
#       4 components = []
#
# File /Users/osu/opt/anaconda3/lib/python3.9/site-packages/music21/converter/__init__.py:1312, in parse(value, forceSource, number, format, **keywords)
#    1309     raise FileNotFoundError(f'Cannot find file in {str(value)}')
#    1310 elif isinstance(value, str) and common.findFormatFile(value) is not None:
#    1311     # assume mistyped file path
# -> 1312     raise FileNotFoundError(f'Cannot find file in {str(value)}')
#    1313 else:
#    1314     # all else, including MidiBytes
#    1315     return parseData(value, number=number, format=format, **keywords)
#
# FileNotFoundError: Cannot find file in doduri.xml

# %%
for naemamdaero in doduriakbo.recurse():
    components.append(naemamdaero)

# %%
components

# %%
doduriakbo.plot('pianoroll')

# %%
doduriakbo.plot('histogram', 'pitch')

# %%
doduriakbo.analyze('key')

# %%
doduriakbo.show()

# %%
doduriakbo.show('midi')

# %%
doduriakbo.plot('colorgrid')

# %%
doduriakbo.plot('3dbars')

# %%
doduriakbo.plot('scatterweighted', 'pitch', 'quarterLength')

# %%
doduriakbo.measures(10, 20).plot('scatterweighted', 'pitch', 'quarterLength')

# %%
from music21 import *
import random

s1 = stream.Stream();
s1.clear()
s1.insert(0, metadata.Metadata())
s1.metadata.title = '계면조 작곡 '
s1.metadata.composer = '온석대학원대학교'
s1.insert(0, meter.TimeSignature('12/8'))
s1.keySignature= key.KeySignature(-3)


for i in range(100):
    randomnote =random.randrange(1, 7)
    if randomnote == 1:
        n1 = note.Note(56)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 2:
        n1 = note.Note(58)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 3:
        n1 = note.Note(60)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 4:
        n1 = note.Note(63)
        n1.quarterLength=0.125
        s1.append(n1)
        n1 = note.Note(62)
        n1.quarterLength=0.375
        s1.append(n1)
    if randomnote == 5:
        n1 = note.Note(65)
        n1.quarterLength=0.5
        s1.append(n1)
    if randomnote == 6:
        n1 = note.Note(68)
        n1.quarterLength=0.5
        s1.append(n1)    
    if randomnote == 7:
        n1 = note.Note(70)
        n1.quarterLength=0.5
        s1.append(n1)

# %%
s1.show()

# %%
s1.show('midi')

# %%
s1.plot('3dbars')

# %%
s1.plot('scatterweighted', 'pitch', 'quarterLength')

# %%
s1.plot('histogram', 'pitch')
